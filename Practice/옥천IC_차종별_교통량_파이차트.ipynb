# %% [markdown]
# <a href="https://colab.research.google.com/github/JYPIT/C/blob/main/Practice/%EC%98%A5%EC%B2%9CIC_%EC%B0%A8%EC%A2%85%EB%B3%84_%EA%B5%90%ED%86%B5%EB%9F%89_%ED%8C%8C%EC%9D%B4%EC%B0%A8%ED%8A%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
 
# %config InlineBackend.figure_format = 'retina'
 
# !apt -qq -y install fonts-nanum
 
import matplotlib.font_manager as fm

fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager._rebuild()
# Out:
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.

# %%
import plotly.express as px
import numpy as np
import pandas as pd

df = pd.read_csv('지역별기간별 교통량 데이터.csv',encoding='utf-8')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126191 entries, 0 to 126190
# Data columns (total 19 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   도로_시작위치  126191 non-null  object
#  1   도로_종료위치  126191 non-null  object
#  2   년        126191 non-null  int64
#  3   월        126191 non-null  int64
#  4   일        126191 non-null  int64
#  5   방향       126191 non-null  int64
#  6   일종_차량수   126191 non-null  int64
#  7   이종_차량수   126191 non-null  int64
#  8   삼종_차량수   126191 non-null  int64
#  9   사종_차량수   126191 non-null  int64
#  10  오종_차량수   126191 non-null  int64
#  11  육종_차량수   126191 non-null  int64
#  12  칠종_차량수   126191 non-null  int64
#  13  팔종_차량수   126191 non-null  int64
#  14  구종_차량수   126191 non-null  int64
#  15  십종_차량수   126191 non-null  int64
#  16  십일종_차량수  126191 non-null  int64
#  17  십이종_차량수  126191 non-null  int64
#  18  전체_차량수   126191 non-null  int64
# dtypes: int64(17), object(2)
# memory usage: 18.3+ MB

# %%
df1 = df[df.도로_시작위치 =='안성IC ']
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 446 entries, 105292 to 105737
# Data columns (total 19 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   도로_시작위치  446 non-null    object
#  1   도로_종료위치  446 non-null    object
#  2   년        446 non-null    int64
#  3   월        446 non-null    int64
#  4   일        446 non-null    int64
#  5   방향       446 non-null    int64
#  6   일종_차량수   446 non-null    int64
#  7   이종_차량수   446 non-null    int64
#  8   삼종_차량수   446 non-null    int64
#  9   사종_차량수   446 non-null    int64
#  10  오종_차량수   446 non-null    int64
#  11  육종_차량수   446 non-null    int64
#  12  칠종_차량수   446 non-null    int64
#  13  팔종_차량수   446 non-null    int64
#  14  구종_차량수   446 non-null    int64
#  15  십종_차량수   446 non-null    int64
#  16  십일종_차량수  446 non-null    int64
#  17  십이종_차량수  446 non-null    int64
#  18  전체_차량수   446 non-null    int64
# dtypes: int64(17), object(2)
# memory usage: 69.7+ KB

# %%
import matplotlib.pyplot as plt
#from pandas import Series

df1 = df[df.도로_종료위치 == ' 옥천IC']
#print(df2.T)

vehicle = df2.iloc[:,6:-1].sum()

vehicle_rest = vehicle[2:].sum() 

vehicle_final = vehicle[:2]

#print(vehicle_final)

vehicle_final.loc['그 외 차량수'] = vehicle_rest

#print(vehicle_rest)

print(vehicle_final)

labels = ['일종 차량수','이종 차량수','그외 차량수']
colors = ['lightblue','lightgreen','silver']
explode = [0.03,0.03,0.03]

plt.figure(figsize=(6,6),dpi=200)
plt.pie(vehicle_final,autopct='%.1f%%',startangle=260,labels=labels,explode=explode,counterclock=False,colors=colors)
plt.title("옥천IC 차종별 차량수")

# %%
df2 = df[df.도로_종료위치 == ' 옥천IC']
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 454 entries, 102502 to 102955
# Data columns (total 19 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   도로_시작위치  454 non-null    object
#  1   도로_종료위치  454 non-null    object
#  2   년        454 non-null    int64
#  3   월        454 non-null    int64
#  4   일        454 non-null    int64
#  5   방향       454 non-null    int64
#  6   일종_차량수   454 non-null    int64
#  7   이종_차량수   454 non-null    int64
#  8   삼종_차량수   454 non-null    int64
#  9   사종_차량수   454 non-null    int64
#  10  오종_차량수   454 non-null    int64
#  11  육종_차량수   454 non-null    int64
#  12  칠종_차량수   454 non-null    int64
#  13  팔종_차량수   454 non-null    int64
#  14  구종_차량수   454 non-null    int64
#  15  십종_차량수   454 non-null    int64
#  16  십일종_차량수  454 non-null    int64
#  17  십이종_차량수  454 non-null    int64
#  18  전체_차량수   454 non-null    int64
# dtypes: int64(17), object(2)
# memory usage: 70.9+ KB

# %%
import matplotlib.pyplot as plt
#from pandas import Series

df2 = df[df.도로_종료위치 == ' 옥천IC']
#print(df2.T)

vehicle = df2.iloc[:,6:-1].sum()

vehicle_rest = vehicle[2:].sum() 

vehicle_final = vehicle[:2]

#print(vehicle_final)

vehicle_final.loc['그 외 차량수'] = vehicle_rest

#print(vehicle_rest)

print(vehicle_final)

labels = ['일종 차량수','이종 차량수','그 외 차량수']
colors = ['lightblue','lightgreen','silver']
explode = [0.03,0.03,0.03]

plt.figure(figsize=(6,6),dpi=200)
plt.pie(vehicle_final,autopct='%.1f%%',startangle=260,labels=labels,explode=explode,counterclock=False,colors=colors)
plt.title("금강IC-옥천IC 차종별 차량수")
# explode=explode, shadow=True)
# Out:
# 일종_차량수     5600468
# 이종_차량수      361648
# 그 외 차량수    2769396
# dtype: int64
# Text(0.5, 1.0, '금강IC-옥천IC 차종별 차량수')
